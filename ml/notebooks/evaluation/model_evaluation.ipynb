# %% [markdown]
# # Prognos — Model Evaluation
#
# Compare trained models across cancer types.
# Run after training notebooks have saved models to `../../models/`.

# %%
import joblib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# from sklearn.metrics import roc_auc_score, classification_report, RocCurveDisplay

sns.set_theme(style='whitegrid')
# %matplotlib inline

# %%
CANCER_TYPES = [
    'lung_cancer', 'breast_cancer', 'colon_cancer', 'prostate_cancer',
    'melanoma', 'cervical_cancer', 'bladder_cancer', 'thyroid_cancer'
]

# TODO: load models and test data, then compute metrics for each type
# for cancer in CANCER_TYPES:
#     model = joblib.load(f'../../models/{cancer}/model.pkl')
#     ...
